# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv("airport.csv"))

# %%
df.head()
# Out:
#    1                               Goroka Airport        Goroka  \
# 0  2                               Madang Airport        Madang
# 1  3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 2  4                               Nadzab Airport        Nadzab
# 3  5  Port Moresby Jacksons International Airport  Port Moresby
# 4  6                  Wewak International Airport         Wewak
#
#    Papua New Guinea  GKA  AYGA  -6.081689834590001  145.391998291  5282  10  \
# 0  Papua New Guinea  MAG  AYMD           -5.207080     145.789001    20  10
# 1  Papua New Guinea  HGU  AYMH           -5.826790     144.296005  5388  10
# 2  Papua New Guinea  LAE  AYNZ           -6.569803     146.725977   239  10
# 3  Papua New Guinea  POM  AYPY           -9.443380     147.220001   146  10
# 4  Papua New Guinea  WWK  AYWK           -3.583830     143.669006    19  10
#
#    U  Pacific/Port_Moresby  airport  OurAirports
# 0  U  Pacific/Port_Moresby  airport  OurAirports
# ...

# %%
df.columns
# Out:
# Index(['Goroka Airport', 'Goroka', 'Papua New Guinea', 'GKA', 'AYGA',
#        '-6.081689834590001', '145.391998291', '5282', '10', 'U',
#        'Pacific/Port_Moresby', 'airport', 'OurAirports'],
#       dtype='object')

# %%
df = df[['Goroka Airport', 'Goroka', 'Papua New Guinea', 'AYGA']]

# %%
df.columns = ["unnamed", "airport_name", "city_name", "country_name"]

# %%
df
# Out:
#                                           unnamed  airport_name  \
# 0                                  Madang Airport        Madang
# 1                    Mount Hagen Kagamuga Airport   Mount Hagen
# 2                                  Nadzab Airport        Nadzab
# 3     Port Moresby Jacksons International Airport  Port Moresby
# 4                     Wewak International Airport         Wewak
# ...                                           ...           ...
# 7692                          Rogachyovo Air Base        Belaya
# 7693                        Ulan-Ude East Airport      Ulan Ude
# 7694                         Krechevitsy Air Base      Novgorod
# 7695                  Desierto de Atacama Airport       Copiapo
# 7696                           Melitopol Air Base     Melitopol
#
#              city_name country_name
# 0     Papua New Guinea         AYMD
# 1     Papua New Guinea         AYMH
# 2     Papua New Guinea         AYNZ
# 3     Papua New Guinea         AYPY
# ...
